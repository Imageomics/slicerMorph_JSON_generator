# %% [markdown]
# ### Transform CSV file of UberonIDs & Labels (with particular formatting) to JSON for SlicerMorph.

# %%
#import required pacakges

import json
import pandas as pd
import numpy as np

# %% [markdown]
# #### Read in CSV and rename `Slicer Label` column for ease of referencing

# %%
df = pd.read_csv("terminology.csv")

# %%
df.sample(10)
# Out:
#        Region  UberonID          UberonLabel          SlicerLabel Paired    R
# 48   Forelimb    100048             Forelimb             Forelimb      Y   20  \
# 63   Hindlimb    100063            Lower Leg            Lower Leg      Y   87
# 79      Spine    100079             Lumbar 3             Lumbar 3    NaN   58
# 60   Hindlimb    100060              Ischium              Ischium      Y  255
# 67   Hindlimb    100067              Patella              Patella      Y  101
# 72      Spine    100072           Cervical 3           Cervical 3    NaN  204
# 19       Head    100019                Vomer                Vomer      Y  219
# 40  Dentition    100040  Maxillary Incisor 3  Maxillary Incisor 3      Y   70
# 22  Dentition    100022    Maxillary Molar 1    Maxillary Molar 1      Y    0
# 69      Spine    100069               Sacrum               Sacrum      Y   41
#
#       G    B                                Notes
# 48  103   94              All long bones + girdle
# 63  197  211  Tibia, fibula and everything distal
# 79  149  252                                  NaN
# 60  249   87                                  NaN
# 67   56  199                                  NaN
# 72   41  150                                  NaN
# 19   46   46                                  NaN
# 40  192  255                                  NaN
# 22  179   92                                  NaN
# 69   95  204                                  NaN

# %% [markdown]
# Look at sample `Region`

# %%
df.loc[df.Region == "Forelimb"]
# Out:
#       Region  UberonID      UberonLabel      SlicerLabel Paired    R    G
# 48  Forelimb    100048         Forelimb         Forelimb      Y   20  103  \
# 49  Forelimb    100049  Pectoral Girdle  Pectoral Girdle      Y   26   52
# 50  Forelimb    100050        Lower Arm        Lower Arm      Y   55  139
# 51  Forelimb    100051          Scapula          Scapula      Y  129  212
# 52  Forelimb    100052         Clavicle         Clavicle      Y  190  250
# 53  Forelimb    100053          Humerus          Humerus      Y  255  255
# 54  Forelimb    100054           Radius           Radius      Y  224  189
# 55  Forelimb    100055             Ulna             Ulna      Y  211  218
#
#       B                                            Notes
# 48   94                          All long bones + girdle
# 49   27  scapula, clavicles, humerus (can be incomplete)
# 50   77                radius + ulna + everything distal
# 51  139                                              NaN
# 52  215                                              NaN
# 53  255                                              NaN
# 54  144                                              NaN
# 55  115                                              NaN

# %%
list(df.loc[df.Region == "Forelimb"].index)
# Out:
# [48, 49, 50, 51, 52, 53, 54, 55]

# %% [markdown]
# #### Generate list of `Region`s with their associated "Types" and the Types' "Modifiers"

# %% [markdown]
# Note that we will adjust the "Modifier" section for appropriate labeling of fused (or potentially fused) bones. I have submitted a question to clarifie the "Modifier" term on the Slicer forum.

# %%
#initialize list for regions and counter for 3dSlicerIntegerLabel

region_list = []
counter = 1
for region in set(df.Region):
    region_idx = list(df.loc[df.Region == region].index)
    #checking if we have a singleton -- Could we have this?
    if len(region_idx) == 1:
         print("Region with no types")
    else:
        region_labels = []
        for i in region_idx:
            #check for paired values & add appropriate Modifiers
            if df.loc[i].Paired == "Y":
                temp_label_dict = {
                    "CodeMeaning": df.loc[i].UberonLabel,
                    "CodingSchemeDesignator": "UBERON",
                    "3dSlicerLabel": df.loc[i].SlicerLabel,
                    "3dSlicerIntegerLabel": counter,                        
                    "CodeValue": str(df.loc[i].UberonID),
                    "contextGroupName": "CommonTissueSegmentationTypes",
                    "paired": "Y",
                    "Modifier": [
                        {
                            "recommendedDisplayRGBValue": [df.loc[i].R, 
                                                            df.loc[i].G, 
                                                            df.loc[i].B],
                            "CodeMeaning": "Right",
                            "CodingSchemeDesignator": "SCT",
                            "3dSlicerLabel": "right" + " " + df.loc[i].SlicerLabel,
                            "3dSlicerIntegerLabel": counter + 1,
                            "cid": "244",
                            "UMLSConceptUID": "C0205090",
                            "CodeValue": "24028007",
                            "contextGroupName": "Laterality",
                            "SNOMEDCTConceptID": "24028007"
                        },
                        {
                            "recommendedDisplayRGBValue": [df.loc[i].R, 
                                                            df.loc[i].G, 
                                                            df.loc[i].B],
                            "CodeMeaning": "Left",
                            "CodingSchemeDesignator": "SCT",
                            "3dSlicerLabel": "left" + " " + df.loc[i].SlicerLabel,
                            "3dSlicerIntegerLabel": counter + 2,
                            "cid": "244",
                            "UMLSConceptUID": "C0205091",
                            "CodeValue": "7771000",
                            "contextGroupName": "Laterality",
                            "SNOMEDCTConceptID": "7771000"
                        },
                        {
                            "recommendedDisplayRGBValue": [df.loc[i].R, 
                                                            df.loc[i].G, 
                                                            df.loc[i].B],
                            "CodeMeaning": "Right and left",
                            "CodingSchemeDesignator": "SCT",
                            "cid": "244",
                            "CodeValue": "0000210",
                            "contextGroupName": "Laterality"
                        }
                        ]
                }
                # increment counter for main + modifiers
                counter += 3
            else:    
                temp_label_dict = {
                    "recommendedDisplayRGBValue": [df.loc[i].R, 
                                                    df.loc[i].G, 
                                                    df.loc[i].B],
                    "CodeMeaning": df.loc[i].UberonLabel, 
                    "CodingSchemeDesignator": "UBERON",
                    "3dSlicerLabel": df.loc[i].SlicerLabel,                       
                    "3dSlicerIntegerLabel": counter,
                    "cid": "7166",
                    "CodeValue": str(df.loc[i].UberonID),
                    "contextGroupName": "CommonTissueSegmentationTypes"
                }
                counter += 1
            #add to list of region's Types
            region_labels.append(temp_label_dict)
            
        #generate region with its corresponding Types
        temp = {"CodeMeaning": region, 
                "CodingSchemeDesignator": "UBERON", 
                "showAnatomy": True,
                "cid": "7150",
                "CodeValue": str(list(df.loc[df.Region == region].UberonID)[0]),  #pull first UberonID?
                "contextGroupName": "SegmentationPropertyCategories",
                "Type": 
                        region_labels
                    }
    #add to list of regions
    region_list.append(temp)

# %% [markdown]
# #### Add `region_list` to "Category" of the "SegmentationCodes" for upper level of the file

# %%
# combine regions with all their type information

file_test = {
        "SegmentationCategoryTypeContextName": "Segmentation category and type - Test",
        "@schema": "https://raw.githubusercontent.com/qiicr/dcmqi/master/doc/schemas/segment-context-schema.json#",
        "SegmentationCodes": {
        "Category":
            region_list 
        }
}

# %% [markdown]
# Helper function for JSON parsing `int64`.
#
# Solution adapted from stackexchange: https://stackoverflow.com/a/60376755.

# %%
#JSON rejecting int64 type, so we must tell it how to parse
#solution adapted from stackexchange: https://stackoverflow.com/a/60376755

def int_converter(obj):
        if isinstance(obj, np.integer):
            return int(obj)

# %% [markdown]
# Generate a test to check our generated `JSON` input is valid on https://qiicr.org/dcmqi/#/validators (recommended JSON validator from Slicer [Docs](https://slicer.readthedocs.io/en/latest/user_guide/modules/terminologies.html)).
#
# Note: this cell is not required.

# %%
#generate test file to check JSON input is valid
#run check on https://qiicr.org/dcmqi/#/validators (recommendation from Slicer Docs)

test = json.dumps(file_test, default = int_converter, indent = 4)
print(test)
# Out:
# {
#     "SegmentationCategoryTypeContextName": "Segmentation category and type - Test",
#     "@schema": "https://raw.githubusercontent.com/qiicr/dcmqi/master/doc/schemas/segment-context-schema.json#",
#     "SegmentationCodes": {
#         "Category": [
#             {
#                 "CodeMeaning": "Hindlimb",
#                 "CodingSchemeDesignator": "UBERON",
#                 "showAnatomy": true,
#                 "cid": "7150",
#                 "CodeValue": "100056",
#                 "contextGroupName": "SegmentationPropertyCategories",
#                 "Type": [
#                     {
#                         "CodeMeaning": "Hindlimb",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Hindlimb",
#                         "3dSlicerIntegerLabel": 1,
#                         "CodeValue": "100056",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     230,
#                                     119,
#                                     80
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Hindlimb",
#                                 "3dSlicerIntegerLabel": 2,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     230,
#                                     119,
#                                     80
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Hindlimb",
#                                 "3dSlicerIntegerLabel": 3,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     230,
#                                     119,
#                                     80
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "recommendedDisplayRGBValue": [
#                             213,
#                             98,
#                             229
#                         ],
#                         "CodeMeaning": "Pelvic gridle",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Pelvic gridle",
#                         "3dSlicerIntegerLabel": 4,
#                         "cid": "7166",
#                         "CodeValue": "100057",
#                         "contextGroupName": "CommonTissueSegmentationTypes"
#                     },
#                     {
#                         "CodeMeaning": "Coxa",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Coxa",
#                         "3dSlicerIntegerLabel": 5,
#                         "CodeValue": "100058",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     127,
#                                     82,
#                                     255
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Coxa",
#                                 "3dSlicerIntegerLabel": 6,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     127,
#                                     82,
#                                     255
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Coxa",
#                                 "3dSlicerIntegerLabel": 7,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     127,
#                                     82,
#                                     255
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Ilium",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Ilium",
#                         "3dSlicerIntegerLabel": 8,
#                         "CodeValue": "100059",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     145,
#                                     235,
#                                     120
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Ilium",
#                                 "3dSlicerIntegerLabel": 9,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     145,
#                                     235,
#                                     120
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Ilium",
#                                 "3dSlicerIntegerLabel": 10,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     145,
#                                     235,
#                                     120
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Ischium",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Ischium",
#                         "3dSlicerIntegerLabel": 11,
#                         "CodeValue": "100060",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     249,
#                                     87
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Ischium",
#                                 "3dSlicerIntegerLabel": 12,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     249,
#                                     87
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Ischium",
#                                 "3dSlicerIntegerLabel": 13,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     249,
#                                     87
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Pubis",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Pubis",
#                         "3dSlicerIntegerLabel": 14,
#                         "CodeValue": "100061",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     236,
#                                     148,
#                                     208
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Pubis",
#                                 "3dSlicerIntegerLabel": 15,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     236,
#                                     148,
#                                     208
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Pubis",
#                                 "3dSlicerIntegerLabel": 16,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     236,
#                                     148,
#                                     208
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Epipubis",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Epipubis",
#                         "3dSlicerIntegerLabel": 17,
#                         "CodeValue": "100062",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     250,
#                                     170,
#                                     50
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Epipubis",
#                                 "3dSlicerIntegerLabel": 18,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     250,
#                                     170,
#                                     50
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Epipubis",
#                                 "3dSlicerIntegerLabel": 19,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     250,
#                                     170,
#                                     50
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Lower Leg",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Lower Leg",
#                         "3dSlicerIntegerLabel": 20,
#                         "CodeValue": "100063",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     87,
#                                     197,
#                                     211
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Lower Leg",
#                                 "3dSlicerIntegerLabel": 21,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     87,
#                                     197,
#                                     211
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Lower Leg",
#                                 "3dSlicerIntegerLabel": 22,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     87,
#                                     197,
#                                     211
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Femur",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Femur",
#                         "3dSlicerIntegerLabel": 23,
#                         "CodeValue": "100064",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     240,
#                                     77,
#                                     115
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Femur",
#                                 "3dSlicerIntegerLabel": 24,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     240,
#                                     77,
#                                     115
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Femur",
#                                 "3dSlicerIntegerLabel": 25,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     240,
#                                     77,
#                                     115
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Tibia",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Tibia",
#                         "3dSlicerIntegerLabel": 26,
#                         "CodeValue": "100065",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     65,
#                                     36,
#                                     128
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Tibia",
#                                 "3dSlicerIntegerLabel": 27,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     65,
#                                     36,
#                                     128
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Tibia",
#                                 "3dSlicerIntegerLabel": 28,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     65,
#                                     36,
#                                     128
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Fibula",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Fibula",
#                         "3dSlicerIntegerLabel": 29,
#                         "CodeValue": "100066",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     120,
#                                     82,
#                                     204
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Fibula",
#                                 "3dSlicerIntegerLabel": 30,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     120,
#                                     82,
#                                     204
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Fibula",
#                                 "3dSlicerIntegerLabel": 31,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     120,
#                                     82,
#                                     204
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Patella",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Patella",
#                         "3dSlicerIntegerLabel": 32,
#                         "CodeValue": "100067",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     101,
#                                     56,
#                                     199
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Patella",
#                                 "3dSlicerIntegerLabel": 33,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     101,
#                                     56,
#                                     199
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Patella",
#                                 "3dSlicerIntegerLabel": 34,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     101,
#                                     56,
#                                     199
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "CodeMeaning": "Dentition",
#                 "CodingSchemeDesignator": "UBERON",
#                 "showAnatomy": true,
#                 "cid": "7150",
#                 "CodeValue": "100022",
#                 "contextGroupName": "SegmentationPropertyCategories",
#                 "Type": [
#                     {
#                         "CodeMeaning": "Maxillary Molar 1",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Maxillary Molar 1",
#                         "3dSlicerIntegerLabel": 35,
#                         "CodeValue": "100022",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     0,
#                                     179,
#                                     92
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Maxillary Molar 1",
#                                 "3dSlicerIntegerLabel": 36,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     0,
#                                     179,
#                                     92
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Maxillary Molar 1",
#                                 "3dSlicerIntegerLabel": 37,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     0,
#                                     179,
#                                     92
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Maxillary Molar 2",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Maxillary Molar 2",
#                         "3dSlicerIntegerLabel": 38,
#                         "CodeValue": "100023",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     144,
#                                     16,
#                                     49
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Maxillary Molar 2",
#                                 "3dSlicerIntegerLabel": 39,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     144,
#                                     16,
#                                     49
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Maxillary Molar 2",
#                                 "3dSlicerIntegerLabel": 40,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     144,
#                                     16,
#                                     49
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Maxillary Molar 3",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Maxillary Molar 3",
#                         "3dSlicerIntegerLabel": 41,
#                         "CodeValue": "100024",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     237,
#                                     76
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Maxillary Molar 3",
#                                 "3dSlicerIntegerLabel": 42,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     237,
#                                     76
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Maxillary Molar 3",
#                                 "3dSlicerIntegerLabel": 43,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     237,
#                                     76
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Maxillary Molar 4",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Maxillary Molar 4",
#                         "3dSlicerIntegerLabel": 44,
#                         "CodeValue": "100025",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     50,
#                                     25,
#                                     91
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Maxillary Molar 4",
#                                 "3dSlicerIntegerLabel": 45,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     50,
#                                     25,
#                                     91
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Maxillary Molar 4",
#                                 "3dSlicerIntegerLabel": 46,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     50,
#                                     25,
#                                     91
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Mandibular Molar M1",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Mandibular Molar M1",
#                         "3dSlicerIntegerLabel": 47,
#                         "CodeValue": "100026",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     78,
#                                     91,
#                                     207
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Mandibular Molar M1",
#                                 "3dSlicerIntegerLabel": 48,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     78,
#                                     91,
#                                     207
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Mandibular Molar M1",
#                                 "3dSlicerIntegerLabel": 49,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     78,
#                                     91,
#                                     207
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Mandibular Molar M2",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Mandibular Molar M2",
#                         "3dSlicerIntegerLabel": 50,
#                         "CodeValue": "100027",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     217,
#                                     131,
#                                     33
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Mandibular Molar M2",
#                                 "3dSlicerIntegerLabel": 51,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     217,
#                                     131,
#                                     33
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Mandibular Molar M2",
#                                 "3dSlicerIntegerLabel": 52,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     217,
#                                     131,
#                                     33
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Mandibular Molar M3",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Mandibular Molar M3",
#                         "3dSlicerIntegerLabel": 53,
# ...
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     16,
#                                     57,
#                                     204
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Tympanic Ring",
#                                 "3dSlicerIntegerLabel": 199,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     16,
#                                     57,
#                                     204
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Tympanic Bulla",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Tympanic Bulla",
#                         "3dSlicerIntegerLabel": 200,
#                         "CodeValue": "100016",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     116,
#                                     217,
#                                     69
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Tympanic Bulla",
#                                 "3dSlicerIntegerLabel": 201,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     116,
#                                     217,
#                                     69
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Tympanic Bulla",
#                                 "3dSlicerIntegerLabel": 202,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     116,
#                                     217,
#                                     69
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "recommendedDisplayRGBValue": [
#                             167,
#                             171,
#                             121
#                         ],
#                         "CodeMeaning": "Hyoid",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Hyoid",
#                         "3dSlicerIntegerLabel": 203,
#                         "cid": "7166",
#                         "CodeValue": "100017",
#                         "contextGroupName": "CommonTissueSegmentationTypes"
#                     },
#                     {
#                         "CodeMeaning": "Lacrymal",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Lacrymal",
#                         "3dSlicerIntegerLabel": 204,
#                         "CodeValue": "100018",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     207,
#                                     218
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Lacrymal",
#                                 "3dSlicerIntegerLabel": 205,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     207,
#                                     218
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Lacrymal",
#                                 "3dSlicerIntegerLabel": 206,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     255,
#                                     207,
#                                     218
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Vomer",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Vomer",
#                         "3dSlicerIntegerLabel": 207,
#                         "CodeValue": "100019",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     219,
#                                     46,
#                                     46
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Vomer",
#                                 "3dSlicerIntegerLabel": 208,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     219,
#                                     46,
#                                     46
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Vomer",
#                                 "3dSlicerIntegerLabel": 209,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     219,
#                                     46,
#                                     46
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Alisphenoid",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Alisphenoid",
#                         "3dSlicerIntegerLabel": 210,
#                         "CodeValue": "100020",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     58,
#                                     149,
#                                     252
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Alisphenoid",
#                                 "3dSlicerIntegerLabel": 211,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     58,
#                                     149,
#                                     252
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Alisphenoid",
#                                 "3dSlicerIntegerLabel": 212,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     58,
#                                     149,
#                                     252
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     },
#                     {
#                         "CodeMeaning": "Orbitosphenoid",
#                         "CodingSchemeDesignator": "UBERON",
#                         "3dSlicerLabel": "Orbitosphenoid",
#                         "3dSlicerIntegerLabel": 213,
#                         "CodeValue": "100021",
#                         "contextGroupName": "CommonTissueSegmentationTypes",
#                         "paired": "Y",
#                         "Modifier": [
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     237,
#                                     217,
#                                     114
#                                 ],
#                                 "CodeMeaning": "Right",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "right Orbitosphenoid",
#                                 "3dSlicerIntegerLabel": 214,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205090",
#                                 "CodeValue": "24028007",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "24028007"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     237,
#                                     217,
#                                     114
#                                 ],
#                                 "CodeMeaning": "Left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "3dSlicerLabel": "left Orbitosphenoid",
#                                 "3dSlicerIntegerLabel": 215,
#                                 "cid": "244",
#                                 "UMLSConceptUID": "C0205091",
#                                 "CodeValue": "7771000",
#                                 "contextGroupName": "Laterality",
#                                 "SNOMEDCTConceptID": "7771000"
#                             },
#                             {
#                                 "recommendedDisplayRGBValue": [
#                                     237,
#                                     217,
#                                     114
#                                 ],
#                                 "CodeMeaning": "Right and left",
#                                 "CodingSchemeDesignator": "SCT",
#                                 "cid": "244",
#                                 "CodeValue": "0000210",
#                                 "contextGroupName": "Laterality"
#                             }
#                         ]
#                     }
#                 ]
#             }
#         ]
#     }
# }

# %% [markdown]
# Save test JSON file

# %%
with open("generation_test.json", "w", encoding = 'utf-8') as fp:
    json.dump(file_test, fp, default = int_converter, indent = 4)
